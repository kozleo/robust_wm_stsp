# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from stabda.utils import xr_load, get_results_path, get_distr_on_times

# %%
results_path = get_results_path()
filename = 'decode_baseline_distr_10_50.nc'
filepath = os.path.join(results_path, filename)

results = xr_load(filepath)

# %%
plt.style.use('sci_style.py')
delays = results.delay.data
n_delays = delays.size
n_sessions = results.session.data.size
T = results.timepts.data.size

distr_start_dict = get_distr_on_times()
x = np.linspace(-2000, 5000, T) / 1000

samp_color = 'g'
test_color = 'b'
dis_color = 'k'

nd_color = 'darkblue'
d_color = 'darkgreen'

alpha_box = 0.2



fig, ax = plt.subplots(2, 3, figsize=(20,8))
ax = ax.ravel()


for i, delay in enumerate(delays):
    test_start = ((delay*1000)+500) * 1e-3
    distr_start = (distr_start_dict[delay])

    ind = np.where(x <= distr_start_dict[delay])[0][-1] - 4
    x_filt = results.timepts[(results.timepts >= distr_start_dict[delay]-0.2)].data
    
    mean_d = results.loc[:,delay,1,x_filt].mean('session')
    x_mod = np.linspace(distr_start - 0.2, 5, mean_d.size)
    
    err_d = results.loc[:,delay,1,x_filt].std('session') / np.sqrt(n_sessions)
    
    ax[i].plot(x_mod, mean_d, color = d_color, label='Distractor')
    ax[i].fill_between(x_mod, mean_d - err_d, mean_d + err_d, color = d_color, alpha=0.3)
    if i == 0:
        ax[i].legend()
    
    ax[i].axhline(1/8, color='r')
    ax[i].axvspan(test_start, test_start+0.500, color=test_color, alpha=alpha_box)
    ax[i].axvspan(distr_start, distr_start+0.250, color=dis_color, alpha=alpha_box)
    ax[i].set_title(f'Delay = {delay}')
    if i >= 2:
        ax[i].set_xlabel('Time (s)')
        
    if i == 0 or i == 3:
        ax[i].set_ylabel('Accuracy')
        
    ax[i].set_ylim([0.4,1])
    ax[i].axhline(0.5, color='k', linestyle='--')
    
ax[5].set_visible(False)
plt.tight_layout()
plt.savefig('figures/decode_pre_distr_baseline.png', dpi=300)
